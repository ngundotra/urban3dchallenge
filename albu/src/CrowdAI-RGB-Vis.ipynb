# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
ddir='/datasets/CrowdAI/predictions/results-RGB/results/resnet34_/'
for x in os.listdir(ddir)[:5]:
    plt.figure()
    plt.imshow(np.load(ddir+x))
